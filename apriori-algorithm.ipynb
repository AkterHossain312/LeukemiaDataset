# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install apyori

# %%
#import all required packages..
import pandas as pd
import numpy as np
from termcolor import colored as cl
from apyori import apriori

# %%
df = pd.read_csv('test.csv')
dft = pd.read_csv('train.csv')

# %%
df = df.rename(columns={"swollen,painless_lymph" : "swollen_painless_lymph","shortness of breath" : "shortness_of_breath","Persistent_weakness _and_fatigue" : "Persistent_weakness_and_fatigue","significant_bruising,bleeding" : "significant_bruising_bleeding"})
dft = dft.rename(columns={"swollen,painless_lymph" : "swollen_painless_lymph","shortness of breath" : "shortness_of_breath","Persistent_weakness _and_fatigue" : "Persistent_weakness_and_fatigue","significant_bruising,bleeding" : "significant_bruising_bleeding"})

# %%
print(cl('X_train shape : {}'.format(dft.shape), attrs = ['bold'],))

# %%
joinData = pd.concat([df, dft], ignore_index=True)

# %%
joinData.head()

# %%
print(cl('X_train shape : {}'.format(joinData.shape), attrs = ['bold'],))

# %%
joinData.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
joinData.head()

# %%
for i in joinData.significant_bruising_bleeding.values:
    if i  == 0:
        joinData.significant_bruising_bleeding.replace(i, ' ', inplace = True)
    else:
        joinData.significant_bruising_bleeding.replace(i, 'significant_bruising_bleeding', inplace = True)

# %%
for i in joinData.swollen_painless_lymph.values:
    if i  == 0:
        joinData.swollen_painless_lymph.replace(i, ' ', inplace = True)
    else:
        joinData.swollen_painless_lymph.replace(i, 'swollen_painless_lymph', inplace = True)

# %%
for i in joinData.Persistent_weakness_and_fatigue.values:
    if i  == 0:
        joinData.Persistent_weakness_and_fatigue.replace(i, ' ', inplace = True)
    else:
        joinData.Persistent_weakness_and_fatigue.replace(i, 'Persistent_weakness_and_fatigue', inplace = True)

# %%
for i in joinData.shortness_of_breath.values:
    if i  == 0:
        joinData.shortness_of_breath.replace(i, ' ', inplace = True)
    else:
        joinData.shortness_of_breath.replace(i, 'shortness_of_breath', inplace = True)

# %%
for i in joinData.bone_pain.values:
    if i  == 0:
        joinData.bone_pain.replace(i, ' ', inplace = True)
    else:
        joinData.bone_pain.replace(i, 'bone_pain', inplace = True)

# %%
for i in joinData.fever.values:
    if i  == 0:
        joinData.fever.replace(i, ' ', inplace = True)
    else:
        joinData.fever.replace(i, 'fever', inplace = True)

# %%
for i in joinData.family_history.values:
    if i  == 0:
        joinData.family_history.replace(i, ' ', inplace = True)
    else:
        joinData.family_history.replace(i, 'family_history', inplace = True)

# %%
for i in joinData.frequent_infections.values:
    if i  == 0:
        joinData.frequent_infections.replace(i, ' ', inplace = True)
    else:
        joinData.frequent_infections.replace(i, 'frequent_infections', inplace = True)

# %%
for i in joinData.Itchy_skin_or_rash.values:
    if i  == 0:
        joinData.Itchy_skin_or_rash.replace(i, ' ', inplace = True)
    else:
        joinData.Itchy_skin_or_rash.replace(i, 'Itchy_skin_or_rash', inplace = True)

# %%
for i in joinData.loss_of_appetite_or_nausea.values:
    if i  == 0:
        joinData.loss_of_appetite_or_nausea.replace(i, ' ', inplace = True)
    else:
        joinData.loss_of_appetite_or_nausea.replace(i, 'loss_of_appetite_or_nausea', inplace = True)

# %%
for i in joinData.enlarged_liver.values:
    if i  == 0:
        joinData.enlarged_liver.replace(i, ' ', inplace = True)
    else:
        joinData.enlarged_liver.replace(i, 'enlarged_liver', inplace = True)

# %%
for i in joinData.oral_cavity.values:
    if i  == 0:
        joinData.oral_cavity.replace(i, ' ', inplace = True)
    else:
        joinData.oral_cavity.replace(i, 'oral_cavity', inplace = True)

# %%
for i in joinData.vision_blurring.values:
    if i  == 0:
        joinData.vision_blurring.replace(i, ' ', inplace = True)
    else:
        joinData.vision_blurring.replace(i, 'vision_blurring', inplace = True)

# %%
for i in joinData.jaundice.values:
    if i  == 0:
        joinData.jaundice.replace(i, ' ', inplace = True)
    else:
        joinData.jaundice.replace(i, 'jaundice', inplace = True)

# %%
for i in joinData.smokes.values:
    if i  == 0:
        joinData.smokes.replace(i, ' ', inplace = True)
    else:
        joinData.smokes.replace(i, 'smokes', inplace = True)

# %%
for i in joinData.leukemia.values:
    if i  == 0:
        joinData.leukemia.replace(i, '', inplace = True)
    else:
        joinData.leukemia.replace(i, 'leukemia', inplace = True)

# %%
for i in joinData.night_sweats.values:
    if i  == 0:
        joinData.night_sweats.replace(i, ' ', inplace = True)
    else:
        joinData.night_sweats.replace(i, 'night_sweats', inplace = True)

# %%
joinData.head()

# %%
joinData.shape[1]

# %%
#joinData.columns = range(joinData.shape[0])

# %%
joinData.head()

# %%
observations = [] 
for i in range(len(joinData)):
    observations.append([str(joinData.values[i,j]) for j in range(17)])

# %%
from apyori import apriori
associations = apriori(observations, min_length = 2, min_support = 0.0110, min_confidence = 0.2, min_lift = 3)

# %%
associations = list(associations)

# %%
print(associations)

# %%
for item in associations:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
